# %% [markdown]
# UNET

# %%
# !python /home/sunghyunahn/anomaly_detection/avss_anomaly_detection/network/unet.py
# Out:
# cuda
# --------------------------------------------------------------------------
#       Layer (type)           Output Shape         Param #     Tr. Param #
# ...
#           inconv-1      [4, 64, 256, 256]          44,032          44,032
#             down-2     [4, 128, 128, 128]         221,696         221,696
#             down-3       [4, 256, 64, 64]         885,760         885,760
#             down-4       [4, 512, 32, 32]       3,540,992       3,540,992
#               up-5       [4, 256, 64, 64]       2,295,040       2,295,040
#               up-6     [4, 128, 128, 128]         574,080         574,080
#               up-7      [4, 64, 256, 256]         143,680         143,680
#           Conv2d-8       [4, 3, 256, 256]           1,731           1,731
# ...
# Total params: 7,707,011
# Trainable params: 7,707,011
# Non-trainable params: 0
# --------------------------------------------------------------------------
# input: torch.Size([4, 12, 256, 256])
# ...

# %% [markdown]
# Proposed Model 1
# (Three Stream Attention, Spatial Attention)

# %%
# !python /home/sunghyunahn/anomaly_detection/avss_anomaly_detection/network/proposed_model1.py
# Out:
# /home/sunghyunahn/anaconda3/envs/dvaa/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# cuda
# Input Shape: torch.Size([4, 3, 4, 256, 256])
# ----------------------------------------------------------------------------------------------------------------------------------------
#         Layer (type)                                                                       Output Shape         Param #     Tr. Param #
# ...
#           ResBlock-1                                                                  [4, 12, 256, 256]           2,592           2,592
#     PatchEmbedding-2                                                                 [4, 48, 4, 64, 64]           2,400           2,400
# ...

# %% [markdown]
# Proposed Model 2
# (Three Stream Attention, ResBlock)

# %%
# !python /home/sunghyunahn/anomaly_detection/avss_anomaly_detection/network/proposed_model2.py
# Out:
# /home/sunghyunahn/anaconda3/envs/dvaa/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# cuda
# Input Shape: torch.Size([4, 3, 4, 256, 256])
# ----------------------------------------------------------------------------------------------------------------------------------------
#         Layer (type)                                                                       Output Shape         Param #     Tr. Param #
# ...
#           ResBlock-1                                                                  [4, 12, 256, 256]           2,592           2,592
#     PatchEmbedding-2                                                                 [4, 48, 4, 64, 64]           2,400           2,400
# ...
